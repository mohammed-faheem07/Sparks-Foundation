# %% [markdown]
# # Exploratory Data Analysis - Retail

# %% [markdown]
# ## Author:
# ### Mohammed Faheem G

# %% [markdown]
# ## About Task:
# ### Perform 'Exploratory Data Analysis' on dataset 'Sample Superstore'

# %% [markdown]
# ## Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading the CSV file

# %%
csv_file = pd.read_csv("SampleSuperstore.csv")
csv_file
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ## Checking whether the dataset has null values or not

# %%
csv_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ## Describing the statistics of thie dataset

# %%
csv_file.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
csv_file.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ## Histogram of the dataset

# %%
csv_file.hist(bins=100, figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'Postal Code'}>,
#         <Axes: title={'center': 'Sales'}>],
#        [<Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'Discount'}>],
#        [<Axes: title={'center': 'Profit'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ## Checking the relation of each column with other column

# %%
co_relation = csv_file.corr()
sns.heatmap(co_relation, xticklabels=co_relation.columns, yticklabels=co_relation.columns,
           annot=True)
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_2876\1574158143.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   co_relation = csv_file.corr()
# <Axes: >

# %%
csv_file['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
csv_file['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
csv_file['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %% [markdown]
# ## Analyzing the sales of different categorys

# %%
plt.bar(csv_file.Category,csv_file.Sales)
plt.xlabel('Category')
plt.ylabel('Sales')
plt.grid()
plt.show()

# %% [markdown]
# ## Analyzing the sales of different ranges

# %%
plt.bar(csv_file.Region,csv_file.Sales)
plt.xlabel('Region')
plt.ylabel('sales')
plt.grid()
plt.show()

# %% [markdown]
# ## Analyzing the profit of different segments

# %%
plt.bar(csv_file.Segment,csv_file.Profit)
plt.xlabel('Segment')
plt.ylabel('Profit')
plt.xticks(rotation=90,fontsize=6)
plt.grid()
plt.show()

# %% [markdown]
# ## Analyzing the profit of different regions

# %%
plt.bar(csv_file.Region,csv_file.Profit)
plt.xlabel('Region')
plt.ylabel('Profit')
plt.grid()
plt.show()

# %% [markdown]
# ## Analyzing the profit of different Categorys

# %%
plt.bar(csv_file.Category,csv_file.Profit)
plt.xlabel('Category')
plt.ylabel('Profit')
plt.grid()
plt.show()

# %% [markdown]
# ## Analyzing the profit of different sub-categorys

# %%
plt.bar(csv_file['Sub-Category'],csv_file.Profit)
plt.xlabel('Sub-Category')
plt.ylabel('Profit')
plt.xticks(rotation=90,fontsize=6)
plt.grid()
plt.show()

# %% [markdown]
# ## Analyzing the profit of different ship modes

# %%
plt.bar(csv_file['Ship Mode'],csv_file.Profit)
plt.xlabel('Ship_Mode')
plt.ylabel('Profit')
plt.grid()
plt.show()

# %% [markdown]
# ## Synopsis:
#
# ### 1. Fix the problems occuring in categories:
# - Technology
# - Office Supplies
# ### 2. Decrease the supply at:
# - Tables (Furniture)
# - Supplies (Office Supplies)
# ### 3. Solve the issues of consumer, if we are still having losses through them,then stop supplying to them.
# ### 4. Solve the probems occuring in:
# - Binders (Office Supplies)
# - Phone (Technology)
# - Machine (Technology)
# - Furnishings (Furniture)
# ### 5. Increase the supply of chairs
# ### 6. Delivering products with standard class is recommended

# %% [markdown]
# # <center>THANK YOU</center>
